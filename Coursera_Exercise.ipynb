# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshit-code-tech/1st-and-2nd-year-practise/blob/main/Coursera_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EX_2

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# EX_3

# %% [markdown]
# ## Introduction
# In this notebook, we summarize some of the most popular tools, languages, and libraries used by data scientists. We also perform simple arithmetic examples using code cells.

# %% [markdown]
# EX_4

# %% [markdown]
# ## Data Science Languages
# Some of the commonly used languages for Data Science include:
# - Python
# - R
# - SQL

# %% [markdown]
# EX_5

# %% [markdown]
# ## Data Science Libraries
# Popular libraries used by data scientists are:
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn

# %% [markdown]
# EX_6

# %% [markdown]
# ## Data Science Tools
#
# | Tool            | Category               |
# |-----------------|-------------------------|
# | Jupyter Notebook | Interactive Development |
# | RStudio          | IDE for R               |
# | Apache Spark     | Big Data Processing     |

# %% [markdown]
# EX_7

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# EX_8

# %%
# This code multiplies and adds numbers
result = (3 * 4) + 5
result
# Out:
# 17

# %% [markdown]
# EX_9

# %%
# This code converts minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# EX_10

# %% [markdown]
# ## Objectives
# - List popular data science languages
# - List commonly used data science libraries
# - Create tables using Markdown
# - Execute arithmetic operations in Python
# - Convert time units using Python code

# %% [markdown]
# EX_11

# %% [markdown]
# ## Author
# SOHAM CHOWDHURY
